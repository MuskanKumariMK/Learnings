# %%
import qrcode as qr

# %%
image = qr.make("https://www.geeksforgeeks.org/generate-qr-code-using-qrcode-in-python/")

# %%
image.save("first-qr.png")

# %%
# QR Code2

# %%
import qrcode

# %%
from PIL import Image

# %%
qr = qrcode.QRCode(version=1,error_correction=qrcode.constants.ERROR_CORRECT_H,box_size=10,border=4)

# %%
qr
